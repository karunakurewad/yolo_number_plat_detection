# %% [markdown]
# **For one image**

# %%
import cv2
import pytesseract
import os
import pandas as pd

# Set path to Tesseract OCR executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Load the Haar Cascade for number plates
cascade_path = "haarcascade_russian_plate_number.xml" 
plate_cascade = cv2.CascadeClassifier(cascade_path)

if plate_cascade.empty():
    print("Error: Failed to load Haar Cascade file.")
    exit()

# Load the image file
image_path = r"C:\Users\DELL\Documents\project\vhical_plate_detection\carrr.jpeg"
image = cv2.imread(image_path)

if image is None:
    print("Error: Image not found")
    exit()

# Create folder to save detected plates
output_folder = "detected_plates"
os.makedirs(output_folder, exist_ok=True)

# Prepare list to store detected plate text
detected_plates = []

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Use Canny edge detection
edges = cv2.Canny(blurred, 100, 200)

# Optionally, dilate edges to strengthen plate contours
dilated = cv2.dilate(edges, None, iterations=1)

# Detect plates using Haar cascade
plates = plate_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

if len(plates) == 0:
    print("No plates detected!")
else:
    for (x, y, w, h) in plates:
        # Draw a rectangle around the detected plate
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

        # Extract the plate region
        plate_region = image[y:y + h, x:x + w]

        # Use OCR to extract text from the plate
        plate_text = pytesseract.image_to_string(plate_region, config='--psm 8').strip()

        if plate_text:
            print(f"Detected Plate: {plate_text}")
            detected_plates.append(plate_text)  # Add plate text to the list

            # Save the plate region image
            plate_image_path = os.path.join(output_folder, f"plate_{x}_{y}.png")
            cv2.imwrite(plate_image_path, plate_region)

            # Display plate text on the image
            cv2.putText(image, plate_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# Save detected plate numbers to an Excel file
if detected_plates:
    df = pd.DataFrame(detected_plates, columns=["Detected Plates"])
    excel_path = "detected_plates.xlsx"  # Path to save the Excel file
    df.to_excel(excel_path, index=False)
    print(f"Detected plates saved to {excel_path}")

# Show the image with detected plates
cv2.imshow('Car Number Plate Detection', image)

# Wait for a key press and close the image window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Detected Plate: "SNKB338A _
# Detected plates saved to detected_plates.xlsx

# %%
import cv2
import pytesseract
import os
import pandas as pd

# Set path to Tesseract OCR executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Load the Haar Cascade for number plates
cascade_path = "haarcascade_russian_plate_number.xml" 
plate_cascade = cv2.CascadeClassifier(cascade_path)

if plate_cascade.empty():
    print("Error: Failed to load Haar Cascade file.")
    exit()

# Create folder to save detected plates
output_folder = "detected_plates"
os.makedirs(output_folder, exist_ok=True)

# Prepare list to store detected plate text
detected_plates = []

# Start capturing video 
path=r"C:\Users\DELL\Documents\project\vhical_plate_detection\demo.mp4"
cap = cv2.VideoCapture(path)  

if not cap.isOpened():
    print("Error: Could not open video stream.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert image to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect plates using Haar cascade
    plates = plate_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Process detected plates
    for (x, y, w, h) in plates:
        # Draw a rectangle around the detected plate
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

        # Extract the plate region
        plate_region = frame[y:y + h, x:x + w]

        # Use OCR to extract text from the plate
        plate_text = pytesseract.image_to_string(plate_region, config='--psm 8').strip()

        if plate_text:
            print(f"Detected Plate: {plate_text}")
            detected_plates.append(plate_text)  # Add plate text to the list

            # Save the plate region image
            plate_image_path = os.path.join(output_folder, f"plate_{x}_{y}.png")
            cv2.imwrite(plate_image_path, plate_region)

            # Display plate text on the image
            cv2.putText(frame, plate_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Show the live video with detected plates
    cv2.imshow('Live Car Number Plate Detection', frame)

    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Save detected plate numbers to an Excel file after the video capture ends
if detected_plates:
    df = pd.DataFrame(detected_plates, columns=["Detected Plates"])
    excel_path = "detected_plates.xlsx"  # Path to save the Excel file
    df.to_excel(excel_path, index=False)
    print(f"Detected plates saved to {excel_path}")

# Release the video capture object and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Detected Plate: Poeiss Je
# Detected Plate: Preiss
# Detected Plate: Pee-iss J!
# Detected Plate: Poeisc J’
# Detected Plate: Pee isc’
# Detected Plate: Pee-iss
# Detected Plate: ea
# Detected Plate: Peeics J
# Detected Plate: Piss
# Detected Plate: P1337
# Detected Plate: =
# Detected Plate: P83
# Detected Plate: YR183JF
# Detected Plate: =a
# Detected Plate: =
# Detected Plate: PR-183-JF
# Detected Plate: =a
# Detected Plate: R183
# Detected Plate: P 183-JF
# Detected Plate: Y R163-JF
# Detected Plate: a
# Detected Plate: P1833
# Detected Plate: -—-_
# Detected Plate: =a
# Detected Plate: __
# Detected Plate: 163
# Detected Plate: <>
# Detected Plate: R183 JF
# Detected Plate: c=
# Detected Plate: P R183- JF
# Detected Plate: = t.
# Detected Plate: =a
# Detected Plate: r=
# Detected Plate: R183 JF
# Detected Plate: am
# Detected Plate: PR-183-JF
# Detected Plate: PD R-183-JF
# Detected Plate: TR183-JF
# Detected Plate: PR183-JF
# Detected Plate: P R-183-JF
# Detected Plate: PR183-JF
# Detected Plate: P R183)
# Detected Plate: Pei63JF
# Detected Plate: ra
# Detected Plate: R183)
# Detected Plate: P R-183-JF
# Detected Plate: R183)
# Detected Plate: PRi63 JF
# Detected Plate: P R183)
# Detected Plate: PF R-183-JF
# Detected Plate: P R-183-JF
# Detected Plate: Pr k-183-J
# Detected Plate: P R-183- JF
# Detected Plate: Pie3JF
# Detected Plate: P13)
# Detected Plate: R183)
# Detected Plate: P1837
# Detected Plate: P1333
# Detected Plate: Peas JF
# Detected Plate: =o
# Detected Plate: =a
# Detected Plate: =m
# Detected Plate: Pkis1 0
# Detected Plate: P16
# Detected Plate: a
# Detected Plate: =
# Detected Plate: a
# Detected Plate: =a
# Detected Plate: =
# Detected Plate: Ea
# Detected Plate: =a
# Detected Plate: Ea
# Detected Plate: =a
# Detected Plate: =a
# Detected Plate: Pssst
# Detected Plate: am
# Detected Plate: ea
# Detected Plate: Pes
# Detected Plate: Pesce
# Detected Plate: sce
# Detected Plate: to
# Detected Plate: iP y-59s0
# Detected Plate: P5047
# Detected Plate: F594
# Detected Plate: P5541)
# Detected Plate: Pix-5940
# Detected Plate: Py-89s si
# Detected Plate: te
# Detected Plate: P eos
# Detected Plate: co
# Detected Plate: iP v-594-J
# Detected Plate: P v-59410
# Detected Plate: iP y-594-19
# Detected Plate: PF x-594
# Detected Plate: Py-594y
# Detected Plate: Px-394
# Detected Plate: x-s9s
# Detected Plate: Pn-sos vy
# Detected Plate: Pv-sos vy
# Detected Plate: Pr n-s94V
# Detected Plate: =
# Detected Plate: Pn-394-3V
# Detected Plate: Pr n-394 JV
# Detected Plate: fr n-3941V
# Detected Plate: Pr N-894-JV
# Detected Plate: n-594-1V
# Detected Plate: n-694-JV
# Detected Plate: [n-894-V
# Detected Plate: fr N-894JV
# Detected Plate: [N-894-JV
# Detected Plate: PN-894-J
# Detected Plate: PN-594-JV
# Detected Plate: PN-894-1V
# Detected Plate: Pr n-894-JV i
# Detected Plate: FP N-894-JV
# Detected Plate: Pr N-894-JV I
# Detected Plate: =
# Detected Plate: PN-894-1)
# Detected Plate: =
# Detected Plate: P N-694-JV
# Detected Plate: co
# Detected Plate: Piso4sy
# Detected Plate: FL-esexn)
# Detected Plate: (reese.
# Detected Plate: ‘Tse
# Detected Plate: fesexn)
# Detected Plate: ELesexn)
# Detected Plate: ‘Eres
# Detected Plate: ‘Tcesexn)
# Detected Plate: Ecesexn)
# Detected Plate: ‘[cesexn)
# Detected Plate: ‘ese
# Detected Plate: (Eessexn)
# Detected Plate: ‘ESSexH)
# Detected Plate: Essex)
# Detected Plate: Ecesexn)
# Detected Plate: (arcu
# Detected Plate: wan
# Detected Plate: ‘Essexn)
# Detected Plate: Prvwin |
# Detected Plate: Eresex)
# Detected Plate: | eee
# Detected Plate: ssexn]
# Detected Plate: “Cesexn]
# Detected Plate: Prrsvsssnseniy
# Detected Plate: Gnsscp
# Detected Plate: eis
# Detected Plate: [essex]
# Detected Plate: my
# Detected Plate: Teese
# Detected Plate: Frvvsnisnsnnrt
# Detected Plate: [oc
# Detected Plate: rrvsaaaanneneest
# Detected Plate: (essen)
# Detected Plate: “Tessar
# Detected Plate: Eessex)
# Detected Plate: Gizescip
# Detected Plate: eam.
# Detected Plate: fizcocyp
# Detected Plate: Gizrscp
# Detected Plate: [essex]
# Detected Plate: csp
# Detected Plate: [eesexn]
# Detected Plate: “Tssem)
# Detected Plate: Team
# Detected Plate: [essex
# Detected Plate: (Esso
# Detected Plate: TLé5exH)
# Detected Plate: asp
# Detected Plate: Grasp
# Detected Plate: Tessern)
# Detected Plate: Girascp
# Detected Plate: eam.
# Detected Plate: (izescp
# Detected Plate: Gres
# Detected Plate: [essex
# Detected Plate: [essex
# Detected Plate: ‘Tem
# Detected Plate: ‘aon.
# Detected Plate: Gensop
# Detected Plate: Garsup
# Detected Plate: “Toesexn) >
# Detected Plate: ‘Cee
# Detected Plate: Gaccup
# Detected Plate: Gzxscp
# Detected Plate: “Toessexn)
# Detected Plate: fers
# Detected Plate: Gixscp
# Detected Plate: (mcs
# Detected Plate: Gzsccp
# Detected Plate: Group
# Detected Plate: G@rzascp
# Detected Plate: Grnop
# Detected Plate: Gzscp
# Detected Plate: sem
# Detected Plate: (@esscp
# Detected Plate: ([eesexa)
# Detected Plate: (easy
# Detected Plate: Grasp
# Detected Plate: Gicascip
# Detected Plate: Gmascup
# Detected Plate: (mascp
# Detected Plate: Gero
# Detected Plate: Grup
# Detected Plate: Grnsup
# Detected Plate: Giro
# Detected Plate: Grasp
# Detected Plate: Tam.
# Detected Plate: Gersop
# Detected Plate: Gesp
# Detected Plate: Gamo
# Detected Plate: Grsscp
# Detected Plate: Gessop
# Detected Plate: Gemop
# Detected Plate: Gem
# Detected Plate: Gano
# Detected Plate: Gero
# Detected Plate: Ges
# Detected Plate: Gere
# Detected Plate: Gescp
# Detected Plate: Gers
# Detected Plate: Gero
# Detected Plate: Gans
# Detected Plate: Grp
# Detected Plate: Taso
# Detected Plate: Gizsup
# Detected Plate: Grau
# Detected Plate: Ea
# Detected Plate: =a
# Detected Plate: PD -c4s-ix
# Detected Plate: =a
# Detected Plate: =a
# Detected Plate: =
# Detected Plate: =
# Detected Plate: ===
# Detected Plate: =m
# Detected Plate: =m
# Detected Plate: ==
# Detected Plate: =x
# Detected Plate: =m
# Detected Plate: =
# Detected Plate: mm
# Detected Plate: =
# Detected Plate: Pcs
# Detected Plate: =
# Detected Plate: =
# Detected Plate: =n
# Detected Plate: P545-Lx
# Detected Plate: =
# Detected Plate: 644-1
# Detected Plate: P-644-Li
# Detected Plate: P6441
# Detected Plate: Pr 634-U
# Detected Plate: Pi534-Ux
# Detected Plate: Pr i-544-Lx
# Detected Plate: PP i-644-1x
# Detected Plate: Pr H-544-Lx
# Detected Plate: Pr -544-ux
# Detected Plate: Pr -544-x
# Detected Plate: 544-1
# Detected Plate: F H-644°Lx
# Detected Plate: Pr ise4-Lx
# Detected Plate: P644-LX
# Detected Plate: P H-644-LX
# Detected Plate: P5441
# Detected Plate: Pr i-644-Ux
# Detected Plate: P-644-LX
# Detected Plate: Pr i-544-Lx
# Detected Plate: BP H-644-Lx
# Detected Plate: OH-644-LX
# Detected Plate: Pr i-644-Lx
# Detected Plate: Pri344-Lx
# Detected Plate: Pisa
# Detected Plate: Pr H-544-Lx
# Detected Plate: Pri-644-LX
# Detected Plate: Pr -644-LX
# Detected Plate: Pr -644-Lx
# Detected Plate: Pi-o44-Ux
# Detected Plate: Pr is44-U
# Detected Plate: Pi-544-Lx
# Detected Plate: Pi-544-Lx
# Detected Plate: Pris44-ux
# Detected Plate: PH-644-LX
# Detected Plate: Pr H-544-Lx
# Detected Plate: PH-644-LX
# Detected plates saved to detected_plates.xlsx
